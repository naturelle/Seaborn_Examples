# %%
import seaborn as sns

# %%
tips = sns.load_dataset("tips")

# %%
titanic = sns.load_dataset("titanic")
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
iris = sns.load_dataset("iris")
iris.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
sns.scatterplot(x="tip", y="total_bill", data=tips,hue="day", size="size", palette="YlGnBu")
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
sns.histplot(tips['tip'], kde=True, bins=15)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
sns.displot(tips['tip'], kde=True, bins=15)

# %%
sns.barplot(x="sex", y="tip",data=tips, palette="YlGnBu",hue="day" )
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
sns.boxplot(x="day", y="total_bill",data=tips,palette="YlGnBu",hue="sex")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x="day", y="tip",data=tips,palette="YlGnBu",hue="sex", dodge=True)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.jointplot(x="tip", y="total_bill",data=tips,palette="YlGnBu", kind="reg")

# %%
sns.jointplot(x="tip", y="total_bill",data=tips,palette="YlGnBu", kind="kde", fill=True, cmap="YlGnBu")

# %%
sns.jointplot(x="tip", y="total_bill",data=tips,palette="YlGnBu", kind="hex", cmap="YlGnBu")

# %%
sns.jointplot(x="tip", y="total_bill",data=tips,palette="YlGnBu",hue="sex")

# %%
sns.pairplot(titanic.select_dtypes(['number']),hue="pclass")

# %%
titanic.corr()
# Out:
# C:\Users\Ebru\AppData\Local\Temp\ipykernel_15792\2964377706.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   titanic.corr()
#             survived    pclass       age     sibsp     parch      fare  \
# survived    1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass     -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age        -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp      -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch       0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare        0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000
# adult_male -0.557080  0.094035  0.280328 -0.253586 -0.349943 -0.182024
# alone      -0.203367  0.135207  0.198270 -0.584471 -0.583398 -0.271832
#
# ...

# %%
titanic.select_dtypes(['number']).corr()
# Out:
#           survived    pclass       age     sibsp     parch      fare
# survived  1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass   -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age      -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp    -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch     0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare      0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000

# %%
sns.heatmap(titanic.select_dtypes(['number']).corr(),annot=True,cmap="icefire")
# Out:
# <Axes: >

# %%
sns.heatmap(titanic.corr(),annot=True,cmap="icefire")
# Out:
# C:\Users\Ebru\AppData\Local\Temp\ipykernel_15792\1269812426.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(titanic.corr(),annot=True,cmap="icefire")
# <Axes: >

# %%
sns.clustermap(iris.drop("species", axis=1))
